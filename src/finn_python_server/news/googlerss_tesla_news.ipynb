# %%
# 필요 패키지 설치: pip install feedparser pandas
import feedparser
from datetime import datetime, timedelta
import pandas as pd

# %%
def generate_google_rss_url(query, start_date, end_date):
    base_url = "https://news.google.com/rss/search?"
    q = f"q={query}+after:{start_date}+before:{end_date}"
    params = "&hl=en-US&gl=US&ceid=US:en"
    return base_url + q + params

def fetch_news_rss_day(query, day: datetime):
    start_date = day.strftime("%Y-%m-%d")
    end_date = (day + timedelta(days=1)).strftime("%Y-%m-%d")
    url = generate_google_rss_url(query, start_date, end_date)
    feed = feedparser.parse(url)

    items = []
    for entry in feed.entries:
        try:
            pub_date = datetime(*entry.published_parsed[:6])
        except Exception:
            continue
        items.append({
            "date": pub_date.strftime("%Y-%m-%d"),
            "title": entry.title,
            "link": entry.link,
            "source": entry.source.title if "source" in entry else "Unknown"
        })

    return items

def get_news_data(start_day, end_day):
    # ✅ 수집 범위: 2025-01-01 ~ 오늘까지

    all_news = []
    current_day = start_day

    while current_day <= end_day:
        daily_news = fetch_news_rss_day("Tesla", current_day)
        all_news.extend(daily_news)
        print(f"✅ {current_day.strftime('%Y-%m-%d')} - {len(daily_news)} items")
        current_day += timedelta(days=1)
    return all_news

def remove_duplicate_titles_by_prefix(df, prefix_length=50):
    seen = set()
    keep_rows = []

    for _, row in df.iterrows():
        prefix = row["title"][:prefix_length].strip().lower()
        if prefix not in seen:
            seen.add(prefix)
            keep_rows.append(row)

    return pd.DataFrame(keep_rows).reset_index(drop=True)

# %%
all_news = get_news_data(datetime(2024, 1, 1), datetime(2024,12,31))
# Out:
# ✅ 2024-01-01 - 89 items
# ✅ 2024-01-02 - 100 items
# ✅ 2024-01-03 - 100 items
# ✅ 2024-01-04 - 100 items
# ✅ 2024-01-05 - 72 items
# ✅ 2024-01-06 - 34 items
# ✅ 2024-01-07 - 43 items
# ✅ 2024-01-08 - 61 items
# ✅ 2024-01-09 - 88 items
# ✅ 2024-01-10 - 100 items
# ✅ 2024-01-11 - 93 items
# ✅ 2024-01-12 - 58 items
# ✅ 2024-01-13 - 27 items
# ✅ 2024-01-14 - 42 items
# ✅ 2024-01-15 - 82 items
# ✅ 2024-01-16 - 100 items
# ✅ 2024-01-17 - 100 items
# ✅ 2024-01-18 - 84 items
# ✅ 2024-01-19 - 39 items
# ✅ 2024-01-20 - 20 items
# ✅ 2024-01-21 - 53 items
# ✅ 2024-01-22 - 73 items
# ✅ 2024-01-23 - 100 items
# ✅ 2024-01-24 - 100 items
# ✅ 2024-01-25 - 100 items
# ✅ 2024-01-26 - 79 items
# ✅ 2024-01-27 - 13 items
# ✅ 2024-01-28 - 59 items
# ✅ 2024-01-29 - 87 items
# ✅ 2024-01-30 - 100 items
# ✅ 2024-01-31 - 100 items
# ✅ 2024-02-01 - 100 items
# ✅ 2024-02-02 - 100 items
# ✅ 2024-02-03 - 40 items
# ✅ 2024-02-04 - 66 items
# ✅ 2024-02-05 - 92 items
# ✅ 2024-02-06 - 75 items
# ✅ 2024-02-07 - 71 items
# ✅ 2024-02-08 - 63 items
# ✅ 2024-02-09 - 43 items
# ✅ 2024-02-10 - 27 items
# ✅ 2024-02-11 - 62 items
# ✅ 2024-02-12 - 90 items
# ✅ 2024-02-13 - 75 items
# ✅ 2024-02-14 - 66 items
# ✅ 2024-02-15 - 62 items
# ✅ 2024-02-16 - 39 items
# ✅ 2024-02-17 - 18 items
# ✅ 2024-02-18 - 29 items
# ✅ 2024-02-19 - 48 items
# ✅ 2024-02-20 - 58 items
# ✅ 2024-02-21 - 59 items
# ✅ 2024-02-22 - 58 items
# ✅ 2024-02-23 - 41 items
# ✅ 2024-02-24 - 35 items
# ✅ 2024-02-25 - 59 items
# ✅ 2024-02-26 - 79 items
# ✅ 2024-02-27 - 100 items
# ✅ 2024-02-28 - 100 items
# ✅ 2024-02-29 - 95 items
# ✅ 2024-03-01 - 58 items
# ✅ 2024-03-02 - 40 items
# ✅ 2024-03-03 - 60 items
# ✅ 2024-03-04 - 99 items
# ✅ 2024-03-05 - 100 items
# ✅ 2024-03-06 - 100 items
# ✅ 2024-03-07 - 100 items
# ✅ 2024-03-08 - 65 items
# ✅ 2024-03-09 - 9 items
# ✅ 2024-03-10 - 40 items
# ✅ 2024-03-11 - 76 items
# ✅ 2024-03-12 - 80 items
# ✅ 2024-03-13 - 64 items
# ✅ 2024-03-14 - 74 items
# ✅ 2024-03-15 - 66 items
# ✅ 2024-03-16 - 29 items
# ✅ 2024-03-17 - 44 items
# ✅ 2024-03-18 - 59 items
# ✅ 2024-03-19 - 53 items
# ✅ 2024-03-20 - 59 items
# ✅ 2024-03-21 - 57 items
# ✅ 2024-03-22 - 35 items
# ✅ 2024-03-23 - 23 items
# ✅ 2024-03-24 - 39 items
# ✅ 2024-03-25 - 63 items
# ✅ 2024-03-26 - 52 items
# ✅ 2024-03-27 - 53 items
# ✅ 2024-03-28 - 61 items
# ✅ 2024-03-29 - 45 items
# ✅ 2024-03-30 - 24 items
# ✅ 2024-03-31 - 56 items
# ✅ 2024-04-01 - 100 items
# ✅ 2024-04-02 - 100 items
# ✅ 2024-04-03 - 85 items
# ✅ 2024-04-04 - 100 items
# ✅ 2024-04-05 - 100 items
# ✅ 2024-04-06 - 36 items
# ✅ 2024-04-07 - 64 items
# ✅ 2024-04-08 - 96 items
# ✅ 2024-04-09 - 80 items
# ✅ 2024-04-10 - 52 items
# ✅ 2024-04-11 - 66 items
# ✅ 2024-04-12 - 59 items
# ✅ 2024-04-13 - 37 items
# ✅ 2024-04-14 - 97 items
# ✅ 2024-04-15 - 100 items
# ✅ 2024-04-16 - 100 items
# ✅ 2024-04-17 - 100 items
# ✅ 2024-04-18 - 100 items
# ✅ 2024-04-19 - 100 items
# ✅ 2024-04-20 - 40 items
# ✅ 2024-04-21 - 100 items
# ✅ 2024-04-22 - 100 items
# ✅ 2024-04-23 - 100 items
# ✅ 2024-04-24 - 100 items
# ✅ 2024-04-25 - 100 items
# ✅ 2024-04-26 - 81 items
# ✅ 2024-04-27 - 34 items
# ✅ 2024-04-28 - 86 items
# ✅ 2024-04-29 - 100 items
# ✅ 2024-04-30 - 83 items
# ✅ 2024-05-01 - 79 items
# ✅ 2024-05-02 - 71 items
# ✅ 2024-05-03 - 57 items
# ✅ 2024-05-04 - 41 items
# ✅ 2024-05-05 - 54 items
# ✅ 2024-05-06 - 78 items
# ✅ 2024-05-07 - 75 items
# ✅ 2024-05-08 - 71 items
# ✅ 2024-05-09 - 77 items
# ✅ 2024-05-10 - 57 items
# ✅ 2024-05-11 - 26 items
# ✅ 2024-05-12 - 48 items
# ✅ 2024-05-13 - 59 items
# ✅ 2024-05-14 - 57 items
# ✅ 2024-05-15 - 71 items
# ✅ 2024-05-16 - 74 items
# ✅ 2024-05-17 - 48 items
# ✅ 2024-05-18 - 23 items
# ✅ 2024-05-19 - 36 items
# ✅ 2024-05-20 - 62 items
# ✅ 2024-05-21 - 49 items
# ✅ 2024-05-22 - 43 items
# ✅ 2024-05-23 - 53 items
# ✅ 2024-05-24 - 38 items
# ✅ 2024-05-25 - 17 items
# ✅ 2024-05-26 - 25 items
# ✅ 2024-05-27 - 50 items
# ✅ 2024-05-28 - 50 items
# ✅ 2024-05-29 - 40 items
# ✅ 2024-05-30 - 54 items
# ✅ 2024-05-31 - 22 items
# ✅ 2024-06-01 - 25 items
# ✅ 2024-06-02 - 33 items
# ✅ 2024-06-03 - 57 items
# ✅ 2024-06-04 - 63 items
# ✅ 2024-06-05 - 53 items
# ✅ 2024-06-06 - 60 items
# ✅ 2024-06-07 - 58 items
# ✅ 2024-06-08 - 37 items
# ✅ 2024-06-09 - 53 items
# ✅ 2024-06-10 - 75 items
# ✅ 2024-06-11 - 87 items
# ✅ 2024-06-12 - 100 items
# ✅ 2024-06-13 - 100 items
# ✅ 2024-06-14 - 100 items
# ✅ 2024-06-15 - 38 items
# ✅ 2024-06-16 - 68 items
# ✅ 2024-06-17 - 94 items
# ✅ 2024-06-18 - 77 items
# ✅ 2024-06-19 - 57 items
# ✅ 2024-06-20 - 65 items
# ✅ 2024-06-21 - 44 items
# ✅ 2024-06-22 - 31 items
# ✅ 2024-06-23 - 43 items
# ✅ 2024-06-24 - 84 items
# ✅ 2024-06-25 - 82 items
# ✅ 2024-06-26 - 58 items
# ✅ 2024-06-27 - 53 items
# ✅ 2024-06-28 - 37 items
# ✅ 2024-06-29 - 20 items
# ✅ 2024-06-30 - 43 items
# ✅ 2024-07-01 - 95 items
# ✅ 2024-07-02 - 100 items
# ✅ 2024-07-03 - 76 items
# ✅ 2024-07-04 - 60 items
# ✅ 2024-07-05 - 50 items
# ✅ 2024-07-06 - 27 items
# ✅ 2024-07-07 - 61 items
# ✅ 2024-07-08 - 93 items
# ✅ 2024-07-09 - 87 items
# ✅ 2024-07-10 - 100 items
# ✅ 2024-07-11 - 100 items
# ✅ 2024-07-12 - 36 items
# ✅ 2024-07-13 - 32 items
# ✅ 2024-07-14 - 58 items
# ✅ 2024-07-15 - 89 items
# ✅ 2024-07-16 - 78 items
# ✅ 2024-07-17 - 74 items
# ✅ 2024-07-18 - 77 items
# ✅ 2024-07-19 - 50 items
# ✅ 2024-07-20 - 30 items
# ✅ 2024-07-21 - 62 items
# ✅ 2024-07-22 - 100 items
# ✅ 2024-07-23 - 100 items
# ✅ 2024-07-24 - 100 items
# ✅ 2024-07-25 - 64 items
# ✅ 2024-07-26 - 28 items
# ✅ 2024-07-27 - 23 items
# ✅ 2024-07-28 - 61 items
# ✅ 2024-07-29 - 100 items
# ✅ 2024-07-30 - 100 items
# ✅ 2024-07-31 - 69 items
# ✅ 2024-08-01 - 67 items
# ✅ 2024-08-02 - 47 items
# ✅ 2024-08-03 - 18 items
# ✅ 2024-08-04 - 35 items
# ✅ 2024-08-05 - 0 items
# ✅ 2024-08-06 - 68 items
# ✅ 2024-08-07 - 67 items
# ✅ 2024-08-08 - 59 items
# ✅ 2024-08-09 - 51 items
# ✅ 2024-08-10 - 28 items
# ✅ 2024-08-11 - 62 items
# ✅ 2024-08-12 - 82 items
# ✅ 2024-08-13 - 74 items
# ✅ 2024-08-14 - 75 items
# ✅ 2024-08-15 - 53 items
# ✅ 2024-08-16 - 35 items
# ✅ 2024-08-17 - 26 items
# ✅ 2024-08-18 - 55 items
# ✅ 2024-08-19 - 97 items
# ✅ 2024-08-20 - 100 items
# ✅ 2024-08-21 - 100 items
# ✅ 2024-08-22 - 80 items
# ✅ 2024-08-23 - 33 items
# ✅ 2024-08-24 - 46 items
# ✅ 2024-08-25 - 68 items
# ✅ 2024-08-26 - 92 items
# ✅ 2024-08-27 - 100 items
# ✅ 2024-08-28 - 91 items
# ✅ 2024-08-29 - 68 items
# ✅ 2024-08-30 - 53 items
# ✅ 2024-08-31 - 30 items
# ✅ 2024-09-01 - 31 items
# ✅ 2024-09-02 - 72 items
# ✅ 2024-09-03 - 92 items
# ✅ 2024-09-04 - 79 items
# ✅ 2024-09-05 - 63 items
# ✅ 2024-09-06 - 42 items
# ✅ 2024-09-07 - 46 items
# ✅ 2024-09-08 - 75 items
# ✅ 2024-09-09 - 90 items
# ✅ 2024-09-10 - 83 items
# ✅ 2024-09-11 - 74 items
# ✅ 2024-09-12 - 83 items
# ✅ 2024-09-13 - 75 items
# ✅ 2024-09-14 - 31 items
# ✅ 2024-09-15 - 41 items
# ✅ 2024-09-16 - 58 items
# ✅ 2024-09-17 - 73 items
# ✅ 2024-09-18 - 78 items
# ✅ 2024-09-19 - 62 items
# ✅ 2024-09-20 - 48 items
# ✅ 2024-09-21 - 28 items
# ✅ 2024-09-22 - 58 items
# ✅ 2024-09-23 - 68 items
# ✅ 2024-09-24 - 62 items
# ✅ 2024-09-25 - 63 items
# ✅ 2024-09-26 - 54 items
# ✅ 2024-09-27 - 44 items
# ✅ 2024-09-28 - 27 items
# ✅ 2024-09-29 - 76 items
# ✅ 2024-09-30 - 100 items
# ✅ 2024-10-01 - 100 items
# ✅ 2024-10-02 - 100 items
# ✅ 2024-10-03 - 59 items
# ✅ 2024-10-04 - 38 items
# ✅ 2024-10-05 - 21 items
# ✅ 2024-10-06 - 37 items
# ✅ 2024-10-07 - 66 items
# ✅ 2024-10-08 - 84 items
# ✅ 2024-10-09 - 100 items
# ✅ 2024-10-10 - 100 items
# ✅ 2024-10-11 - 100 items
# ✅ 2024-10-12 - 26 items
# ✅ 2024-10-13 - 52 items
# ✅ 2024-10-14 - 83 items
# ✅ 2024-10-15 - 81 items
# ✅ 2024-10-16 - 59 items
# ✅ 2024-10-17 - 80 items
# ✅ 2024-10-18 - 65 items
# ✅ 2024-10-19 - 17 items
# ✅ 2024-10-20 - 45 items
# ✅ 2024-10-21 - 74 items
# ✅ 2024-10-22 - 100 items
# ✅ 2024-10-23 - 100 items
# ✅ 2024-10-24 - 100 items
# ✅ 2024-10-25 - 61 items
# ✅ 2024-10-26 - 29 items
# ✅ 2024-10-27 - 42 items
# ✅ 2024-10-28 - 63 items
# ✅ 2024-10-29 - 59 items
# ✅ 2024-10-30 - 56 items
# ✅ 2024-10-31 - 48 items
# ✅ 2024-11-01 - 24 items
# ✅ 2024-11-02 - 13 items
# ✅ 2024-11-03 - 34 items
# ✅ 2024-11-04 - 50 items
# ✅ 2024-11-05 - 58 items
# ✅ 2024-11-06 - 55 items
# ✅ 2024-11-07 - 65 items
# ✅ 2024-11-08 - 55 items
# ✅ 2024-11-09 - 24 items
# ✅ 2024-11-10 - 58 items
# ✅ 2024-11-11 - 75 items
# ✅ 2024-11-12 - 69 items
# ✅ 2024-11-13 - 64 items
# ✅ 2024-11-14 - 34 items
# ✅ 2024-11-15 - 50 items
# ✅ 2024-11-16 - 18 items
# ✅ 2024-11-17 - 71 items
# ✅ 2024-11-18 - 100 items
# ✅ 2024-11-19 - 73 items
# ✅ 2024-11-20 - 66 items
# ✅ 2024-11-21 - 60 items
# ✅ 2024-11-22 - 40 items
# ✅ 2024-11-23 - 30 items
# ✅ 2024-11-24 - 70 items
# ✅ 2024-11-25 - 100 items
# ✅ 2024-11-26 - 81 items
# ✅ 2024-11-27 - 53 items
# ✅ 2024-11-28 - 48 items
# ✅ 2024-11-29 - 48 items
# ✅ 2024-11-30 - 34 items
# ✅ 2024-12-01 - 91 items
# ✅ 2024-12-02 - 100 items
# ✅ 2024-12-03 - 100 items
# ✅ 2024-12-04 - 84 items
# ✅ 2024-12-05 - 74 items
# ✅ 2024-12-06 - 41 items
# ✅ 2024-12-07 - 24 items
# ✅ 2024-12-08 - 52 items
# ✅ 2024-12-09 - 100 items
# ✅ 2024-12-10 - 100 items
# ✅ 2024-12-11 - 100 items
# ✅ 2024-12-12 - 82 items
# ✅ 2024-12-13 - 52 items
# ✅ 2024-12-14 - 33 items
# ✅ 2024-12-15 - 67 items
# ✅ 2024-12-16 - 77 items
# ✅ 2024-12-17 - 66 items
# ✅ 2024-12-18 - 77 items
# ✅ 2024-12-19 - 95 items
# ✅ 2024-12-20 - 70 items
# ✅ 2024-12-21 - 33 items
# ✅ 2024-12-22 - 64 items
# ✅ 2024-12-23 - 76 items
# ✅ 2024-12-24 - 41 items
# ✅ 2024-12-25 - 11 items
# ✅ 2024-12-26 - 23 items
# ✅ 2024-12-27 - 18 items
# ✅ 2024-12-28 - 10 items
# ✅ 2024-12-29 - 18 items
# ✅ 2024-12-30 - 33 items
# ✅ 2024-12-31 - 43 items

# %%
# ✅ DataFrame으로 정리 후 저장
df = pd.DataFrame(all_news)
df.sort_values(by="date", inplace=True)
df = df[["date", "title", "link", "source"]]
df["date"] = pd.to_datetime(df["date"])

# ✅ 중복 제거 (title 기준)
df.drop_duplicates(subset="title", inplace=True)


# 2차로 앞부분 50글자 기준 중복 제거
df = remove_duplicate_titles_by_prefix(df, prefix_length=50)

df.to_csv("~/Downloads/tsla_news_train.csv", index=False)
print("✅ 저장 완료: tsla_news.csv")
df.head(10)
# Out:
# ✅ 저장 완료: tsla_news.csv
#         date                                              title  \
# 0 2024-01-01  Tesla is sneakily testing Fremont-built refres...
# 1 2024-01-01  Tesla Cybertruck’s eyebrow-raising windshield ...
# 2 2024-01-01  Can I Charge My Non-Tesla at a Tesla Charging ...
# 3 2024-01-01  The World's Best Factory Drag Car Is No Match ...
# 4 2024-01-01  Tesla Model 3 Battery Size, Voltage, And Charg...
# 5 2024-01-01  Tesla lashes Reuters for 'wildly misleading' s...
# 6 2024-01-01  Tesla's EV Business Faces 'Challenges' In 2024...
# 7 2024-01-01  BYD beats Tesla for a second straight year aft...
# 8 2024-01-01  Here are the only Tesla vehicles that now have...
# 9 2024-01-01  Tesla car spotted on Bengaluru roads, sparks b...
#
#                                                 link  \
# 0  https://news.google.com/rss/articles/CBMinAFBV...
# 1  https://news.google.com/rss/articles/CBMiigFBV...
# 2  https://news.google.com/rss/articles/CBMihAFBV...
# 3  https://news.google.com/rss/articles/CBMiggFBV...
# 4  https://news.google.com/rss/articles/CBMihgFBV...
# 5  https://news.google.com/rss/articles/CBMiqgFBV...
# 6  https://news.google.com/rss/articles/CBMiygFBV...
# 7  https://news.google.com/rss/articles/CBMiogFBV...
# 8  https://news.google.com/rss/articles/CBMie0FVX...
# 9  https://news.google.com/rss/articles/CBMi1AFBV...
#
#                       source
# 0                   Electrek
# 1               Yahoo! Autos
# 2                How-To Geek
# 3                 Motor1.com
# 4                  Top Speed
# 5                  CarExpert
# 6  Investor's Business Daily
# 7                       CNBC
# 8                   Electrek
# 9            Hindustan Times

# %%
import requests
from bs4 import BeautifulSoup

def extract_article_text(url):
    try:
        headers = {'User-Agent': 'Mozilla/5.0'}
        res = requests.get(url, headers=headers, timeout=5)
        soup = BeautifulSoup(res.text, 'html.parser')

        # 기사 본문 파싱: <p> 태그 모두 연결
        paragraphs = soup.find_all("p")
        text = '\n'.join(p.get_text() for p in paragraphs)

        return text.strip()
    except Exception as e:
        return "[ERROR] " + str(e)

# %%
from tqdm import tqdm

df["content"] = [
    extract_article_text(url) for url in tqdm(df["link"][:10])
]
df.to_csv("tesla_news_with_body_2025.csv", index=False)
# Out:
# 100%|██████████| 5998/5998 [1:32:56<00:00,  1.08it/s]
